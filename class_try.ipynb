# %%
class speaker():
    def __init__(self):
        self.template = "{who} really love {people}"
    
    def speak(self):
        print(self.template.format(who="kerui", people="liuyaxin"))
        print(self.template)
        

kerui = speaker()
kerui.speak()
# Out:
# kerui really love liuyaxin
# {who} really love {people}
